# %%
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.metrics.pairwise import cosine_similarity

# %%
import pandas as pd
df = pd.read_csv('developer_dataset.csv')

# %%
df.head()
# Out:
#    user_id        tech_field                      programming_languages  \
# 0        1               IoT                              Java, Arduino
# 1        2     Cybersecurity     Python, C, Metasploit, Wireshark, Nmap
# 2        3  Game Development  C++, Unity, Unreal Engine, C#, JavaScript
# 3        4              Web3          JavaScript, WebAssembly, Rust, Go
# 4        5      UI/UX Design          Adobe XD, Sketch, Figma, InVision
#
#        region            availability  \
# 0  Chandigarh  Part-time availability
# 1      Mumbai  Full-time availability
# 2   Ahmedabad  Available for projects
# 3      Jaipur  Part-time availability
# 4     Kolkata  Full-time availability
#
#                                                goals  experience
# 0                    Connect devices to the internet          10
# 1  Protect systems from cyber threats, Enhance ne...           4
# 2                 Work on 2D and 3D game development          10
# 3  Create decentralized applications (DApps), Imp...           9
# 4                   Create appealing user interfaces           3

# %%
import string

# Preprocess text data
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()

    # Remove punctuation
    text = ''.join([char for char in text if char not in string.punctuation])

    # Tokenize the text (split into words)
    tokens = text.split()

    return ' '.join(tokens)

# Apply preprocessing to relevant columns
df['tech_field'] = df['tech_field'].apply(preprocess_text)
df['programming_languages'] = df['programming_languages'].apply(preprocess_text)
df['goals'] = df['goals'].apply(preprocess_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text columns
tfidf_matrix = tfidf_vectorizer.fit_transform(df['tech_field'] + ' ' + df['programming_languages'] + ' ' + df['goals'])

# Check the shape of the TF-IDF matrix
print(tfidf_matrix.shape)
# Out:
# (500, 127)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity between users
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Check the shape of the cosine similarity matrix
print(cosine_sim.shape)

# Example: Get recommendations for user with user_id = 1
user_id = 1
sim_scores = list(enumerate(cosine_sim[user_id - 1]))
sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
# Out:
# (500, 500)

# %%
from prettytable import PrettyTable

# Define a function to format and print the recommendations
def print_recommendations(user_id, recommendations):
    user_profile = df[df['user_id'] == user_id]

    # Create a table to display user's profile
    user_table = PrettyTable()
    user_table.field_names = user_profile.columns
    user_table.add_row(user_profile.values[0])

    # Create a table to display recommendations
    recommendations_table = PrettyTable()
    recommendations_table.field_names = user_profile.columns

    for recommended_user_id in recommendations:
        recommended_profile = df[df['user_id'] == recommended_user_id]
        recommendations_table.add_row(recommended_profile.values[0])

    # Print user's profile and recommendations
    print("User Profile:")
    print(user_table)
    print("\nRecommendations for user", user_id, ":")
    print(recommendations_table)

# Input system to get the user's ID
user_id = int(input("Enter your user ID: "))

# Get recommendations for the entered user ID
recommendations = get_recommendations(user_id)

# Print the user's profile and recommendations
print_recommendations(user_id, recommendations)
# Out:
# Enter your user ID: 6
# User Profile:
# +---------+------------+-----------------------+---------+------------------------+--------------------------------------------------------------------------+------------+
# | user_id | tech_field | programming_languages |  region |      availability      |                                  goals                                   | experience |
# +---------+------------+-----------------------+---------+------------------------+--------------------------------------------------------------------------+------------+
# |    6    | blockchain |          rust         | Chennai | Part-time availability | develop blockchainbased applications explore cryptocurrency technologies |     1      |
# +---------+------------+-----------------------+---------+------------------------+--------------------------------------------------------------------------+------------+
#
# Recommendations for user 6 :
# +---------+------------+-------------------------+-----------+------------------------+-------------------------------------------------------------------------------------------------------------------+------------+
# | user_id | tech_field |  programming_languages  |   region  |      availability      |                                                       goals                                                       | experience |
# +---------+------------+-------------------------+-----------+------------------------+-------------------------------------------------------------------------------------------------------------------+------------+
# |   349   | blockchain |            go           |   Jaipur  | Part-time availability |                      explore cryptocurrency technologies develop blockchainbased applications                     |     9      |
# |   324   | blockchain | go rust solidity java c | Ahmedabad | Full-time availability |                      develop blockchainbased applications explore cryptocurrency technologies                     |     9      |
# |    22   | blockchain |           java          |  Chennai  | Part-time availability |                      explore cryptocurrency technologies develop blockchainbased applications                     |     3      |
# |   213   | blockchain |         solidity        |  Kolkata  | Full-time availability |                      develop blockchainbased applications explore cryptocurrency technologies                     |     9      |
# |   178   | blockchain |           rust          | Ahmedabad | Available for projects | ensure security in decentralized systems develop blockchainbased applications explore cryptocurrency technologies |     2      |
# +---------+------------+-------------------------+-----------+------------------------+-------------------------------------------------------------------------------------------------------------------+------------+
